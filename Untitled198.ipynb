# %% [markdown]
# <a href="https://colab.research.google.com/github/pscabral/IFMASOFTEX_1/blob/main/Untitled198.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mega.py

from mega import Mega

# Crie uma instância da classe Mega
mega = Mega()

# Cole o link completo do Mega.nz (incluindo a chave)
url = "https://mega.nz/file/xutxkLoY#5ycY65KDsxtwEobjIycZoITipxk92yA3yQEgkImDYgM"

# Use o link completo para fazer o download
mega.download_url(url)

# !unzip GroceryStoreDataset_.zip

# %%
# !pip install albumentations

import os
import time
from tqdm import tqdm
import numpy as np
import cv2
from albumentations import Compose, Rotate, HorizontalFlip, RandomScale, RandomBrightnessContrast, MultiplicativeNoise, GridDistortion

try:
    import albumentations
    print("Albumentations instalado com sucesso!")
except ImportError:
    print("Erro ao importar Albumentations. Certifique-se de que está instalado corretamente.")

def perform_augmentation(image):
    seq = Compose([
        Rotate(limit=(-10, 10), interpolation=cv2.INTER_LINEAR, always_apply=True),
        HorizontalFlip(p=0.5),
        RandomScale(scale_limit=(1.0, 1.5), interpolation=cv2.INTER_LINEAR, always_apply=True),
        RandomBrightnessContrast(brightness_limit=(-0.2, 0.2), contrast_limit=(-0.2, 0.2), always_apply=True),
        MultiplicativeNoise(multiplier=(0.8, 1.2), per_channel=True, always_apply=True),
        GridDistortion(num_steps=5, distort_limit=0.3, interpolation=cv2.INTER_LINEAR, border_mode=cv2.BORDER_REFLECT_101, always_apply=True),
    ])

    augmented_image = seq(image=image)['image']
    return augmented_image

def apply_data_augmentation(input_dir, augmentation_factor):
    for subdir, _, files in os.walk(input_dir):
        image_files = [f for f in files if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]

        print(f"Encontrados {len(image_files)} arquivos de imagem em {subdir}")

        for image_file in tqdm(image_files, desc=f"Aumentando dados em {subdir}"):
            image_path = os.path.join(subdir, image_file)

            original_image = cv2.imread(image_path)
            if original_image is None:
                print(f"Erro ao carregar a imagem: {image_path}")
                continue

            num_augmented_images = int(len(image_files) * augmentation_factor)

            file_name, file_extension = os.path.splitext(image_file)

            for i in range(num_augmented_images):
                augmented_image = perform_augmentation(original_image)

                timestamp = int(time.time() * 1000)
                output_file = os.path.join(subdir, f"{file_name}_{i}_{timestamp}{file_extension}")
                cv2.imwrite(output_file, augmented_image)

    print(f"Aumento de dados concluído para o conjunto {input_dir}")

datasets = [
    "/content/GroceryStoreDataset_/train",
    "/content/GroceryStoreDataset_/test",
]

for input_dir in datasets:
    total_images = sum([len(files) for _, _, files in os.walk(input_dir)])
    augmentation_factor = 0.1
    apply_data_augmentation(input_dir, augmentation_factor)
# Out:
# ...
# Albumentations instalado com sucesso!
# Encontrados 0 arquivos de imagem em /content/GroceryStoreDataset_/train
# Aumentando dados em /content/GroceryStoreDataset_/train: 0it [00:00, ?it/s]
# Encontrados 33 arquivos de imagem em /content/GroceryStoreDataset_/train/Oatly-Natural-Oatghurt
# Aumentando dados em /content/GroceryStoreDataset_/train/Oatly-Natural-Oatghurt: 100%|██████████| 33/33 [00:03<00:00, 10.86it/s]
# Encontrados 37 arquivos de imagem em /content/GroceryStoreDataset_/train/Peach
# Aumentando dados em /content/GroceryStoreDataset_/train/Peach: 100%|██████████| 37/37 [00:03<00:00, 10.41it/s]
# Encontrados 29 arquivos de imagem em /content/GroceryStoreDataset_/train/Arla-Ecological-Medium-Fat-Milk
# Aumentando dados em /content/GroceryStoreDataset_/train/Arla-Ecological-Medium-Fat-Milk: 100%|██████████| 29/29 [00:01<00:00, 16.52it/s]
# Encontrados 30 arquivos de imagem em /content/GroceryStoreDataset_/train/Alpro-Fresh-Soy-Milk
# ...

# %%
import numpy as np
import pandas as pd
import random
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
from keras.applications.mobilenet import MobileNet, preprocess_input
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense,BatchNormalization, Flatten, MaxPool2D
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from keras.layers import Conv2D, Reshape
from tensorflow.keras.utils import Sequence
from keras.backend import epsilon
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
import cv2

from sklearn.metrics import classification_report, confusion_matrix

import os

import warnings
warnings.filterwarnings('ignore')

# %%
train_dir = "../content/GroceryStoreDataset_/train"
train_class=os.listdir(train_dir)
print(train_class)

val_dir = "../content/GroceryStoreDataset_/val"
val_class=os.listdir(val_dir)
print(val_class)

test_dir = "../content/GroceryStoreDataset_/test"
test_class=os.listdir(test_dir)
print(test_class)
# Out:
# ['Oatly-Natural-Oatghurt', 'Peach', 'Arla-Ecological-Medium-Fat-Milk', 'Alpro-Fresh-Soy-Milk', 'Garant-Ecological-Standard-Milk', 'Regular-Tomato', 'Orange', 'Arla-Medium-Fat-Milk', 'Garant-Ecological-Medium-Fat-Milk', 'Apple-Royal-Gala', 'Passion-Fruit', 'Red-Beet', 'Arla-Ecological-Sour-Cream', 'Arla-Sour-Cream', 'Arla-Standard-Milk', 'Floury-Potato', 'Apple-Golden-Delicious', 'Mango', 'Pomegranate', 'Asparagus', 'Yoggi-Strawberry-Yoghurt', 'Kiwi', 'Arla-Natural-Yoghurt', 'Solid-Potato', 'Watermelon-Melon', 'God-Morgon-Orange-Red-Grapefruit-Juice', 'Yoggi-Vanilla-Yoghurt', 'Tropicana-Golden-Grapefruit-Juice', 'Tropicana-Juice-Smooth-Juice', 'Sweet-Potato', 'Cucumber', 'Apple-Granny-Smith', 'Alpro-Blueberry-Soyghurt', 'Garlic', 'Bravo-Apple-Juice', 'God-Morgon-Apple-Juice', 'Valio-Vanilla-Yoghurt', 'Pear-Conference', 'God-Morgon-Red-Grapefruit-Juice', 'Red-Grapefruit', 'Apple-Pink-Lady', 'Alpro-Vanilla-Soyghurt', 'Brown-Cap-Mushroom', 'Yellow-Bell-Pepper', 'Cabbage', 'Avocado', 'Ban
# ...

# %%
x=[] # array value of the images
y=[] # the labels of the images

for folder in os.listdir(train_dir):
    image_list=os.listdir(train_dir+"/"+folder)
    for img_name in image_list:
        # Loading images
        img=image.load_img(train_dir+"/"+folder+"/"+img_name,target_size=(224,224))
        img=image.img_to_array(img)

        # Transfer Learning: Preprocess of MobileNetV2 model to our images before passing it to MobileNetV2
        img=preprocess_input(img)

        x.append(img) # appending image array
        y.append(train_class.index(folder)) # appending class index to the array

print("Preparing Training Dataset Completed.")
# Out:
# Preparing Training Dataset Completed.

# %%
val_images=[]
val_images_Original=[]
val_image_label=[]

for folder in os.listdir(val_dir):
    image_list=os.listdir(val_dir+"/"+folder)
    for img_name in image_list:
        # Loading images
        img=image.load_img(val_dir+"/"+folder+"/"+img_name,target_size=(224,224))

        # Converting to arrarys
        img=image.img_to_array(img)

        # Saving original images, will be used just for display at the end
        val_images_Original.append(img.copy())
        img=preprocess_input(img)

        # Appending arrays
        val_images.append(img)
        val_image_label.append(val_class.index(folder))

print("Preparing Validation Dataset Completed.")
# Out:
# Preparing Validation Dataset Completed.

# %%
test_images=[]
test_images_Original=[]
test_image_label=[]

for folder in os.listdir(test_dir):
    image_list=os.listdir(test_dir+"/"+folder)
    for img_name in image_list:
        # Loading images
        img=image.load_img(test_dir+"/"+folder+"/"+img_name,target_size=(224,224))

        # Converting to arrarys
        img=image.img_to_array(img)

        # Saving original images, will be used just for display at the end
        test_images_Original.append(img.copy())
        img=preprocess_input(img)

        # Appending arrays
        test_images.append(img)
        test_image_label.append(test_class.index(folder))

print("Preparing Test Dataset Completed.")
# Out:
# Preparing Test Dataset Completed.

# %%
print("Training Dataset")

x=np.array(x) # Converting to np arrary to pass to the model
print(x.shape)

y=to_categorical(y) # onehot encoding of the labels
# print(y)
print(y.shape)

# Validation Dataset
print("Validation Dataset")

val_images=np.array(val_images)
print(val_images.shape)

val_image_label=to_categorical(val_image_label) # onehot encoding of the labels)
print(val_image_label.shape)

print("Test Dataset")

test_images=np.array(test_images)
print(test_images.shape)

test_image_label=to_categorical(test_image_label) # onehot encoding of the labels)
print(test_image_label.shape)
# Out:
# Training Dataset
# (11049, 224, 224, 3)
# (11049, 81)
# Validation Dataset
# (296, 224, 224, 3)
# (296, 60)
# Test Dataset
# (10062, 224, 224, 3)
# (10062, 81)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2,random_state=5)
print("Splitting data for train and test completed.")
# Out:
# Splitting data for train and test completed.

# %%
rand_images1 = random.sample(os.listdir("../content/GroceryStoreDataset_/train/Banana"), 8)
rand_images2 = random.sample(os.listdir("../content/GroceryStoreDataset_/train/Lime"), 8)

# %%
fig = plt.figure(figsize=(10,10))
for i, im in enumerate(rand_images1):
    plt.subplot(2,4 , i+1)
    im = cv2.imread(os.path.join("../content/GroceryStoreDataset_/train/Banana", im))
    plt.imshow(im)
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
for i, im in enumerate(rand_images2):
    plt.subplot(2,4 , i+1)
    im = cv2.imread(os.path.join("../content/GroceryStoreDataset_/train/Lime", im))
    plt.imshow(im)
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
mnet = MobileNetV2(include_top = False, weights = "imagenet" ,input_shape=(224,224,3))
# Out:
# ...
# 9406464/9406464 [==============================] - 0s 0us/step

# %%
tf.keras.backend.clear_session()

model = Sequential([mnet,
                    GlobalAveragePooling2D(),
                    Dense(512, activation = "relu"),
                    BatchNormalization(),
                    Dropout(0.3),
                    Dense(128, activation = "relu"),
                    Dropout(0.1),
                    # Dense(32, activation = "relu"),
                    # Dropout(0.3),
                    Dense(81, activation = "softmax")])

model.layers[0].trainable = False

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics="accuracy")

model.summary()
Model: "sequential"
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  global_average_pooling2d (  (None, 1280)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               655872
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 81)                10449
#
# ...
# Total params: 2992017 (11.41 MB)
# Trainable params: 733009 (2.80 MB)
# Non-trainable params: 2259008 (8.62 MB)
# _________________________________________________________________

# %%
def scheduler(epoch):
    if epoch <= 2:
        return 0.001
    elif epoch > 2 and epoch <= 15:
        return 0.0001
    else:
        return 0.00001

lr_callbacks = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
EPOCHS = 20
hist = model.fit(xtrain, ytrain, epochs=EPOCHS, callbacks=[lr_callbacks], validation_data=(xtest,ytest))
# Out:
# Epoch 1/20
# 277/277 [==============================] - 134s 471ms/step - loss: 1.1386 - accuracy: 0.7185 - val_loss: 0.2687 - val_accuracy: 0.9303 - lr: 0.0010
# Epoch 2/20
# 277/277 [==============================] - 125s 451ms/step - loss: 0.2038 - accuracy: 0.9440 - val_loss: 0.1808 - val_accuracy: 0.9434 - lr: 0.0010
# Epoch 3/20
# 277/277 [==============================] - 121s 438ms/step - loss: 0.1241 - accuracy: 0.9645 - val_loss: 0.1392 - val_accuracy: 0.9557 - lr: 0.0010
# Epoch 4/20
# 277/277 [==============================] - 122s 440ms/step - loss: 0.0634 - accuracy: 0.9846 - val_loss: 0.0617 - val_accuracy: 0.9824 - lr: 1.0000e-04
# Epoch 5/20
# 277/277 [==============================] - 129s 466ms/step - loss: 0.0387 - accuracy: 0.9930 - val_loss: 0.0531 - val_accuracy: 0.9846 - lr: 1.0000e-04
# Epoch 6/20
# 277/277 [==============================] - 124s 448ms/step - loss: 0.0317 - accuracy: 0.9954 - val_loss: 0.0524 - val_accuracy: 0.9846 - lr: 1.0000e-04
# ...

# %%
epochs = 20
train_loss = hist.history['loss']
val_loss = hist.history['val_loss']
train_acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
xc = range(epochs)

plt.figure(1,figsize=(7,5))
plt.plot(xc,train_loss)
plt.plot(xc,val_loss)
plt.xlabel('num of Epochs')
plt.ylabel('loss')
plt.title('train_loss vs val_loss')
plt.grid(True)
plt.legend(['train','val'])
#print plt.style.available # use bmh, classic,ggplot for big pictures
plt.style.use(['classic'])

plt.figure(2,figsize=(7,5))
plt.plot(xc,train_acc)
plt.plot(xc,val_acc)
plt.xlabel('num of Epochs')
plt.ylabel('accuracy')
plt.title('train_acc vs val_acc')
plt.grid(True)
plt.legend(['train','val'],loc=4)
#print plt.style.available # use bmh, classic,ggplot for big pictures
plt.style.use(['classic'])

# %%
def predict(img_name, model):
    img=image.load_img(img_name,target_size=(224,224))
    img=image.img_to_array(img)
    plt.imshow(img.astype('int32'))
    plt.show()
    img=preprocess_input(img)
    prediction=model.predict(img.reshape(1,224,224,3))
    output=np.argmax(prediction)
    print(train_class[output])


# This function plots the image supplied in array
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img.astype('int32'))
    predicted_label=np.argmax(predictions_array)
    true_label=np.argmax(true_label)

# %%
predictions=[]

for img in test_images:
    img=img.reshape(1,224,224,3)
    predictions.append(model.predict(img))
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# ...
# 1/1 [==============================] - 0s 62ms/step
# ...
# ...
# 1/1 [==============================] - 0s 49ms/step

# %%
pred_labels = model.predict(test_images)
# Out:
# 315/315 [==============================] - 117s 372ms/step

# %%
def roundoff(arr):
    """To round off according to the argmax of each predicted label array. """
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

print(classification_report(test_image_label, pred_labels, target_names=test_class))
# Out:
#                                         precision    recall  f1-score   support
#
#                 Oatly-Natural-Oatghurt       0.79      0.86      0.82       120
#                                  Peach       0.72      0.78      0.75       144
#        Arla-Ecological-Medium-Fat-Milk       0.73      0.61      0.66        87
#                   Alpro-Fresh-Soy-Milk       0.63      0.61      0.62        84
#        Garant-Ecological-Standard-Milk       0.54      0.32      0.40        22
#                         Regular-Tomato       0.93      0.97      0.95       235
#                                 Orange       0.45      0.56      0.50       336
#                   Arla-Medium-Fat-Milk       0.56      0.43      0.48       136
#      Garant-Ecological-Medium-Fat-Milk       0.71      0.85      0.77       140
#                       Apple-Royal-Gala       0.67      0.43      0.52       448
#                          Passion-Fruit       0.37      0.41      0.39        81
# ...

# %%
pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(test_image_label, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(24, 36), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels= test_class,
                yticklabels=test_class)

plt.title('GroceryStoreDataset')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)

# %%
predict("../content/imagem_teste/milho02.jpg",model)
# Out:
# 1/1 [==============================] - 0s 44ms/step
# Apple-Red-Delicious
