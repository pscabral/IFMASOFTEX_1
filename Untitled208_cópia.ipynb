# %% [markdown]
# <a href="https://colab.research.google.com/github/pscabral/IFMASOFTEX_1/blob/main/Untitled208_c%C3%B3pia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mega.py

from mega import Mega

# Crie uma instância da classe Mega
mega = Mega()

# Cole o link completo do Mega.nz (incluindo a chave)
url = "https://mega.nz/file/l2FAQbpZ#A9gvAEo91_VfsG8a3nuKa8zMSd1pHZjkJbXOJBu6fgY"
#url = "https://mega.nz/file/Jj0zHKgI#FORRysIhl08TMeE7j_AQ_g1UyPHC1FNmSH5UHmjBSUM"

# Use o link completo para fazer o download
mega.download_url(url)

# !unzip freshnessfruitsandvegetables.v7i.yolov8.zip
#!unzip Grocery1.v1i.yolov8.zip

# %%
# !pip install ultralytics

# %%
from PIL import Image
import os
import numpy as np
import torch
import random
import pathlib
from torch.utils.data import Dataset
import json
from torchvision import transforms, utils
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO, utils

# %%
model = YOLO("yolov8n.pt")

# %%
class Config:
    CHECKPOINT_DIR = 'checkpoints'
    EXPERIMENT_NAME = '/content/vegetables'
    DATA_DIR = '../content/vegetables'
    TRAIN_IMAGES_DIR = 'train/images'
    TRAIN_LABELS_DIR = 'train/labels'
    VAL_IMAGES_DIR = 'valid/images'
    VAL_LABELS_DIR = 'valid/labels'
    TEST_IMAGES_DIR = 'test/images'
    TEST_LABELS_DIR = 'test/labels'
    CLASSES = ['fresh apple', 'fresh banana', 'fresh bellpepper', 'fresh carrot', 'fresh cucumber', 'fresh mango', 'fresh orange', 'fresh potato', 'rotten apple', 'rotten banana', 'rotten carrot', 'rotten cucumber', 'rotten mango', 'rotten orange', 'rotten potato', 'rotten tomato', 'rottenbellpepper']
    NUM_CLASSES = len(CLASSES)
    DATALOADER_PARAMS = {'batch_size': 16, 'num_workers': 2}

# %%
config = Config()

# %%
train_images_dir = os.path.join(config.DATA_DIR, config.TRAIN_IMAGES_DIR)
train_labels_dir = os.path.join(config.DATA_DIR, config.TRAIN_LABELS_DIR)

num_images = 5

image_files = [f for f in pathlib.Path(train_images_dir).iterdir() if f.is_file()]

random.shuffle(image_files)

selected_image_files = image_files[:num_images]

colors = [(255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 255, 0), (0, 255, 255), (255, 0, 255),
          (128, 0, 0), (0, 128, 0), (0, 0, 128), (128, 128, 0), (0, 128, 128), (128, 0, 128),
          (64, 0, 0), (0, 64, 0), (0, 0, 64), (64, 64, 0), (0, 64, 64), (64, 0, 64)]

for selected_image_file in selected_image_files:
    demo_image = selected_image_file

    demo_label = pathlib.Path(train_labels_dir) / f"{selected_image_file.stem}.txt"

    image = cv2.imread(str(demo_image))

    class_list = config.CLASSES

    height, width, _ = image.shape

    with open(demo_label, "r") as file1:
        for line in file1.readlines():

            split = line.split(" ")

            class_id = int(split[0])

            if 0 <= class_id < len(colors):

                color = colors[class_id]
                clazz = class_list[class_id]

                x, y, w, h = map(float, split[1:5])

                box = [int(x * width), int(y * height), int(w * width), int(h * height)]

                cv2.rectangle(image, (box[0], box[1]), (box[0] + box[2], box[1] + box[3]), color, 2)

                cv2.rectangle(image, (box[0], box[1] - 20), (box[0] + box[2], box[1]), color, -1)

                cv2.putText(image, clazz, (box[0], box[1] - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0))

            else:
                print(f"ID da classe inválido: {class_id}. Certifique-se de que está dentro da faixa [0, {len(colors) - 1}].")

    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

    image = cv2.resize(image, (600, 600))
    plt.show()

# %%
# !cat /content/vegetables/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 17
# names: ['fresh apple', 'fresh banana', 'fresh bellpepper', 'fresh carrot', 'fresh cucumber', 'fresh mango', 'fresh orange', 'fresh potato', 'rotten apple', 'rotten banana', 'rotten carrot', 'rotten cucumber', 'rotten mango', 'rotten orange', 'rotten potato', 'rotten tomato', 'rottenbellpepper']
#
# roboflow:
#   workspace: college-74jj5
#   project: freshness-fruits-and-vegetables
#   version: 7
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/college-74jj5/freshness-fruits-and-vegetables/dataset/7

# %%
! yolo task=detect mode=train model=yolov8n.pt imgsz=640 data=/content/vegetables/data.yaml epochs=10 batch=8 name=yolov8n_custom
# Out:
# Ultralytics YOLOv8.0.218 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from ultralytics import YOLO

# Carregar um modelo
model = YOLO('yolov8n.pt')  # carregar um modelo oficial
model = YOLO('/content/runs/detect/yolov8n_custom2/weights/best.pt')  # carregar um modelo personalizado

# Validar o modelo
metrics = model.val()  # nenhum argumento necessário, conjunto de dados e configurações lembrados
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # uma lista contém map50-95 de cada categoria
# Out:
# Ultralytics YOLOv8.0.217 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3009158 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/vegetables/valid/labels.cache... 256 images, 0 backgrounds, 0 corrupt: 100%|██████████| 256/256 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:23<00:00,  1.47s/it]
#                    all        256        636      0.729      0.669      0.725      0.403
#                  apple        256         76      0.689      0.882      0.856      0.457
#                 banana        256         25      0.823       0.96      0.965      0.544
#            bell_pepper        256         74      0.864      0.942      0.962      0.589
#                 carrot        256         27      0.505      0.556      0.625      0.359
#            cauliflower        256         15          1      0.987      0.995      0.577
# ...

# %%
# !yolo detect predict model='/content/runs/detect/yolov8n_custom2/weights/best.pt' source='/content/tresfrutas03.jpg'

# %%
# !yolo export model='/content/runs/detect/yolov8n_custom2/weights/best.pt' format=onnx

# %%
# !wget https://v.ftcdn.net/05/04/94/58/700_F_504945825_f12koCu5yYCuqOAILunCp3MgvsNf7G46_ST.mp4 -O fruits.mp4
# Out:
# --2023-11-25 20:20:21--  https://v.ftcdn.net/05/04/94/58/700_F_504945825_f12koCu5yYCuqOAILunCp3MgvsNf7G46_ST.mp4
# Resolving v.ftcdn.net (v.ftcdn.net)... 151.101.1.167, 151.101.65.167, 151.101.129.167, ...
# Connecting to v.ftcdn.net (v.ftcdn.net)|151.101.1.167|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2439355 (2.3M) [video/mp4]
# Saving to: ‘fruits.mp4’
#
# fruits.mp4          100%[===================>]   2.33M  --.-KB/s    in 0.03s
#
# 2023-11-25 20:20:21 (71.2 MB/s) - ‘fruits.mp4’ saved [2439355/2439355]

# %%
# For video
from ultralytics import YOLO

# Load custom trained YOLOv8 model
model = YOLO("/content/runs/detect/yolov8n_custom2/weights/best.pt")

# Use the model to detect object
model.predict(source="/content/fruits.mp4", show=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-a34dbeaae8d0> in <cell line: 8>()
#       6
#       7 # Use the model to detect object
# ----> 8 model.predict(source="/content/fruits.mp4", show=false)
#
# NameError: name 'false' is not defined

# %%
# !pip install opencv-python

# %%
from ultralytics import YOLO
model = YOLO("yolo-Weights/yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 176MB/s]

# %%
from ultralytics import YOLO
import cv2
import math
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("/content/yolov8n.pt")

# object classes
classNames = CLASSES = ['apple', 'banana', 'bell_pepper', 'carrot', 'cauliflower', 'chillies', 'cucumber', 'garlic', 'grapes', 'mango', 'mushroom', 'onion', 'orange', 'pear', 'potato', 'promegranate', 'tomato', 'watermelon']

while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING ⚠️ 'source' is missing. Using 'source=/usr/local/lib/python3.10/dist-packages/ultralytics/assets'.
#
# Confidence ---> 0.88
# Class name --> chillies
# Confidence ---> 0.87
# Class name --> apple
# Confidence ---> 0.86
# Class name --> apple
# Confidence ---> 0.83
# Class name --> apple
# Confidence ---> 0.27
# Class name --> apple
# Confidence ---> 0.26
# Class name --> onion
# image 1/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 74.3ms
# Confidence ---> 0.84
# Class name --> apple
# Confidence ---> 0.82
# Class name --> apple
# Confidence ---> 0.3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-105-c58e3ed7e4c7> in <cell line: 15>()
#      35             # class name
#      36             cls = int(box.cls[0])
# ---> 37             print("Class name -->", classNames[cls])
#      38
# ...

# %%
from ultralytics import YOLO
import cv2
import math

# Start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# Model initialization
model = YOLO("/content/yolov8n.pt")

# Object classes
classNames = CLASSES = ['apple', 'banana', 'bell_pepper', 'carrot', 'cauliflower', 'chillies', 'cucumber', 'garlic', 'grapes', 'mango', 'mushroom', 'onion', 'orange', 'pear', 'potato', 'promegranate', 'tomato', 'watermelon']

while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # Process detection results
    for r in results:
        boxes = r.boxes

        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Convert to int values
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            confidence = math.ceil((box.conf[0] * 100)) / 100
            print("Confidence --->", confidence)

            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Object Detection', img)

    # Press 'q' to exit
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING ⚠️ 'source' is missing. Using 'source=/usr/local/lib/python3.10/dist-packages/ultralytics/assets'.
#
# Confidence ---> 0.88
# Class name --> chillies
# Confidence ---> 0.87
# Class name --> apple
# Confidence ---> 0.86
# Class name --> apple
# Confidence ---> 0.83
# Class name --> apple
# Confidence ---> 0.27
# Class name --> apple
# Confidence ---> 0.26
# Class name --> onion
# image 1/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 95.7ms
# Confidence ---> 0.84
# Class name --> apple
# Confidence ---> 0.82
# Class name --> apple
# Confidence ---> 0.3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-100-2d623fbdf039> in <cell line: 16>()
#      30
#      31             cls = int(box.cls[0])
# ---> 32             print("Class name -->", classNames[cls])
#      33
# ...

# %%
from ultralytics import YOLO
import cv2
import math

# Start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# Model initialization
model = YOLO("/content/yolov8n.pt")

# Object classes
classNames = CLASSES = ['apple', 'banana', 'bell_pepper', 'carrot', 'cauliflower', 'chillies', 'cucumber', 'garlic', 'grapes', 'mango', 'mushroom', 'onion', 'orange', 'pear', 'potato', 'promegranate', 'tomato', 'watermelon']

while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # Process detection results
    for r in results:
        boxes = r.boxes

        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Convert to int values
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            confidence = math.ceil((box.conf[0] * 100)) / 100
            print("Confidence --->", confidence)

            cls = int(box.cls[0])

            # Check if the class index is within the valid range
            if 0 <= cls < len(classNames):
                print("Class name -->", classNames[cls])
            else:
                print("Invalid class index:", cls)

            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Object Detection', img)

    # Press 'q' to exit
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING ⚠️ 'source' is missing. Using 'source=/usr/local/lib/python3.10/dist-packages/ultralytics/assets'.
#
# Confidence ---> 0.88
# Class name --> chillies
# Confidence ---> 0.87
# Class name --> apple
# Confidence ---> 0.86
# Class name --> apple
# Confidence ---> 0.83
# Class name --> apple
# Confidence ---> 0.27
# Class name --> apple
# Confidence ---> 0.26
# Class name --> onion
# image 1/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 73.5ms
# Confidence ---> 0.84
# Class name --> apple
# Confidence ---> 0.82
# Class name --> apple
# Confidence ---> 0.3
# Invalid class index: 27
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-101-286fc81323bc> in <cell line: 16>()
#      42             color = (255, 0, 0)
#      43             thickness = 2
# ...

# %%
from ultralytics import YOLO
import cv2
import math

# Start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# Model initialization
model = YOLO("/content/yolov8n.pt")

# Get the class names from the model
classNames = model.names

while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # Process detection results
    for r in results:
        boxes = r.boxes

        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Convert to int values
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            confidence = math.ceil((box.conf[0] * 100)) / 100
            print("Confidence --->", confidence)

            cls = int(box.cls[0])

            # Check if the class index is within the valid range
            if 0 <= cls < len(classNames):
                print("Class name -->", classNames[cls])
            else:
                print("Invalid class index:", cls)

            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Object Detection', img)

    # Press 'q' to exit
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING ⚠️ 'source' is missing. Using 'source=/usr/local/lib/python3.10/dist-packages/ultralytics/assets'.
#
# Confidence ---> 0.88
# Class name --> bus
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.26
# Class name --> stop sign
# image 1/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 72.9ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.3
# Class name --> tie
# image 2/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/zidane.jpg: 384x640 2 persons, 1 tie, 58.3ms
# Speed: 2.4ms preprocess, 65.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# ...

# %%
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
import cv2
import math

# Model initialization
model = YOLO("/content/yolov8n.pt")

# Get the class names from the model
classNames = model.names

# Load images
image_paths = ["/usr/local/lib/python3.10/dist-packages/ultralytics/assets/bus.jpg",
               "/usr/local/lib/python3.10/dist-packages/ultralytics/assets/zidane.jpg"]

for image_path in image_paths:
    img = cv2.imread(image_path)
    results = model(img, stream=True)

    # Process detection results
    for r in results:
        boxes = r.boxes

        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Convert to int values
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            confidence = math.ceil((box.conf[0] * 100)) / 100
            print("Confidence --->", confidence)

            cls = int(box.cls[0])

            # Check if the class index is within the valid range
            if 0 <= cls < len(classNames):
                print("Class name -->", classNames[cls])
            else:
                print("Invalid class index:", cls)

            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2_imshow('Object Detection', img)
# Out:
# Confidence ---> 0.88
# Class name --> bus
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.26
# Class name --> stop sign
# 0: 640x480 4 persons, 1 bus, 1 stop sign, 57.5ms
# Speed: 4.3ms preprocess, 57.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-e7d88ced6f45> in <cell line: 16>()
#      44             cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)
#      45
# ---> 46     cv2_imshow('Object Detection', img)
#
# TypeError: cv2_imshow() takes 1 positional argument but 2 were given
